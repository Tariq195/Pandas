# %%
import pandas as pd
df = pd.read_csv('Test.csv')
df
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %%
df[['Title','Language']]
# Out:
#                                      Title  Language
# 0                               127 Hours    English
# 1                             3 Backyards    English
# 2                                       3     German
# 3               8: The Mormon Proposition    English
# 4     A Turtle's Tale: Sammy's Adventures    English
# ...                                    ...       ...
# 1599              War & Peace                English
# 1600                    Wings                English
# 1601               Wolf Creek                English
# 1602        Wuthering Heights                English
# 1603  Yu-Gi-Oh! Duel Monsters               Japanese
#
# [1604 rows x 2 columns]

# %%
df.Title
# Out:
# 0                                 127 Hours
# 1                               3 Backyards
# 2                                         3
# 3                 8: The Mormon Proposition
# 4       A Turtle's Tale: Sammy's Adventures
#                         ...
# 1599                War & Peace
# 1600                      Wings
# 1601                 Wolf Creek
# 1602          Wuthering Heights
# 1603    Yu-Gi-Oh! Duel Monsters
# Name: Title, Length: 1604, dtype: object

# %%
df[['Title','Language']].head(20)
# Out:
#                                    Title Language
# 0                             127 Hours   English
# 1                           3 Backyards   English
# 2                                     3    German
# 3             8: The Mormon Proposition   English
# 4   A Turtle's Tale: Sammy's Adventures   English
# 5                   Alice in Wonderland   English
# 6                   Alice in Wonderland   English
# 7                       All Good Things   English
# 8                       Alpha and Omega   English
# 9                                 Amigo   English
# 10                     Anderson's Cross   English
# 11                       Animals United    German
# 12                         Another Year   English
# 13                     Barney's Version   English
# 14                         Barry Munday   English
# 15                            Beginners   English
# 16                      Beneath Hill 60   English
# 17             Beyond the Black Rainbow   English
# ...

# %%
X1=df['Title'][df['Content Rating']=='PG'].head(10)
print(X1)
Z=df.head(20)
Y=Z.loc[Z["Content Rating"]=='PG']

print(Y.Title)
# Out:
# 4          A Turtle's Tale: Sammy's Adventures
# 5                          Alice in Wonderland
# 6                          Alice in Wonderland
# 8                              Alpha and Omega
# 11                              Animals United
# 27    Cats & Dogs: The Revenge of Kitty Galore
# 39                               Despicable Me
# 41                        Diary of a Wimpy Kid
# 51                      Extraordinary Measures
# 55                                     Flipped
# Name: Title, dtype: object
# 4     A Turtle's Tale: Sammy's Adventures
# 5                     Alice in Wonderland
# 6                     Alice in Wonderland
# 8                         Alpha and Omega
# 11                         Animals United
# Name: Title, dtype: object

# %%
df.fillna(0, inplace=True)

# %%
df.shape
# Out:
# (1604, 26)

# %%
df.head(9)
# Out:
#                                   Title    Year  \
# 0                            127 Hours   2010.0
# 1                          3 Backyards   2010.0
# 2                                    3   2010.0
# 3            8: The Mormon Proposition   2010.0
# 4  A Turtle's Tale: Sammy's Adventures   2010.0
# 5                  Alice in Wonderland   2010.0
# 6                  Alice in Wonderland   2010.0
# 7                      All Good Things   2010.0
# 8                      Alpha and Omega   2010.0
#
#                                       Genres Language  Country Content Rating  \
# 0         Adventure|Biography|Drama|Thriller  English      USA              R
# 1                                      Drama  English      USA              R
# 2                       Comedy|Drama|Romance   German  Germany        Unrated
# 3                                Documentary  English      USA              R
# 4                 Adventure|Animation|Family  English   France             PG
# ...

# %%
df.tail(5)
# Out:
#                                      Title  Year  \
# 1599              War & Peace                NaN
# 1600                    Wings                NaN
# 1601               Wolf Creek                NaN
# 1602        Wuthering Heights                NaN
# 1603  Yu-Gi-Oh! Duel Monsters                NaN
#
#                                          Genres  Language    Country  \
# 1599                  Drama|History|Romance|War   English         UK
# 1600                               Comedy|Drama   English        USA
# 1601                      Drama|Horror|Thriller   English  Australia
# 1602                              Drama|Romance   English         UK
# 1603  Action|Adventure|Animation|Family|Fantasy  Japanese      Japan
#
#      Content Rating  Duration  Aspect Ratio  Budget  Gross Earnings  ...  \
# 1599          TV-14       NaN         16.00     NaN             NaN  ...
# 1600            NaN      30.0          1.33     NaN             NaN  ...
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score', 'duration'],
#       dtype='object')

# %%
type(df.Language)
# Out:
# pandas.core.series.Series

# %%
# a=df.head(20)
# print(a['User Votes'].max())
df
df[df.IMDB Score = 551363]
# print(a['User Votes'].mean())
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  0.0
# 1600                    Wings                  0.0
# 1601               Wolf Creek                  0.0
# 1602        Wuthering Heights                  0.0
# 1603  Yu-Gi-Oh! Duel Monsters                  0.0
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# ...

# %%
df[:][df['Reviews by Users'] >= 15]
RU=df[['Title','Reviews by Users','Budget',]][df['Reviews by Users'] == df['Reviews by Users'].max()]
B=df[['Title','Reviews by Users','Budget']][df.Budget==df.Budget.max()]
print(RU)
print(B)
# df.columns
# Out:
#                                     Title  Reviews by Users       Budget
# 1401  Batman v Superman: Dawn of Justice             3018.0  250000000.0
#      Title  Reviews by Users       Budget
# 90  Kites              106.0  600000000.0
